# %%
# !pip install ultralytics --upgrade --quiet
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/kempslysilencieux/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# from ultralytics import YOLO

# # Load the manually downloaded model
# model = YOLO('yolov11x.pt')

# # Train - first iteration
# results_iter1 = model.train(data='dataset/food_dataset.yaml', epochs=50, imgsz=640, lr0=0.01, batch=16)

# %%
# # Train - second iteration (optional tuning)
# results_iter2 = model.train(data='dataset/food_dataset.yaml', epochs=150, imgsz=640, lr0=0.005, batch=32)

# %%
from ultralytics import YOLO

# Load YOLOv11x model
model = YOLO('yolo11x.pt')  # This assumes the model is in the current working directory
# Out:
# ...
# 100%|██████████| 109M/109M [01:06<00:00, 1.72MB/s]

# %%
import os
os.chdir("/Users/kempslysilencieux/Downloads/projects/russian-yolo-food-detection/data/dataset")

# %%
# First training iteration
results_iter1 = model.train(
    data='/Users/kempslysilencieux/Downloads/projects/russian-yolo-food-detection/data/dataset/food_dataset.yaml',
    epochs=50,
    imgsz=640,
    lr0=0.01,
    batch=16
)
# Out:
# Ultralytics 8.3.162 🚀 Python-3.12.8 torch-2.7.1 CPU (Apple M4 Pro)
# ...

# %%
results_iter1 = model.train(
    data='food_dataset.yaml',
    epochs=50,
    imgsz=640,
    lr0=0.01,
    batch=16
)
# Out:
# Ultralytics 8.3.162 🚀 Python-3.12.8 torch-2.7.1 CPU (Apple M4 Pro)
# ...

# %%
# Second iteration with adjusted hyperparameters
results_iter2 = model.train(
    data='data/dataset/food_dataset.yaml',
    epochs=150,
    imgsz=640,
    lr0=0.005,
    batch=32
)
